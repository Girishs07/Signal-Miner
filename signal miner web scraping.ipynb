# %%
import os
import json
import pandas as pd
import serpapi
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import time


SERP_API_KEY = "38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad"  


companies = [
    "Chargebee", "Plum Insurance", "Yellow.ai", "Graphy", "Kala.ai",
    "Razorpay", "BrowserStack", "Meesho", "Upstox", "Darwinbox",
    "Zoho", "Hasura", "Vidyard", "Fyle", "Dunzo",
    "OfBusiness", "Artivatic", "Stanza Living", "Sigtuple", "Locus"
]


keywords = [
    "Product Manager", "Sales Development", "Software Engineer", "UX Designer",
    "Customer Success", "Marketing", "Data Analyst", "Recruiter", "Engineering Lead"
]


signal_map = {
    "product": "New Product Initiative",
    "software engineer": "Engineering Buildout",
    "sales": "Go-To-Market Expansion",
    "designer": "Design Overhaul",
    "director": "Leadership Upgrade",
    "manager": "Leadership Upgrade",
    "lead": "Leadership Upgrade",
    "vp": "Leadership Upgrade",
    "cxo": "Leadership Upgrade"
}


department_map = {
    "software": "Engineering",
    "engineer": "Engineering",
    "developer": "Engineering",
    "product manager": "Product",
    "pm": "Product",
    "design": "Design",
    "ux": "Design",
    "ui": "Design",
    "sales": "Sales",
    "bd": "Sales",
    "business development": "Sales",
    "marketing": "Marketing",
    "customer success": "CSM",
    "support": "Support",
    "data": "Data",
    "analyst": "Data",
    "devops": "DevOps",
    "qa": "QA",
    "hr": "HR",
    "recruit": "Recruiting",
    "finance": "Finance"
}


seniority_map = {
    "intern": "Intern",
    "internship": "Intern",
    "associate": "Junior",
    "jr": "Junior",
    "junior": "Junior",
    "mid-level": "Mid",
    "mid": "Mid",
    "senior": "Senior",
    "lead": "Lead",
    "principal": "Lead",
    "director": "Director",
    "vp": "VP",
    "cxo": "CXO"
}


def get_department(title):
    title_lower = title.lower()
    for key, dept in department_map.items():
        if key in title_lower:
            return dept
    return "Other"


def get_seniority(title):
    title_lower = title.lower()
    for key, level in seniority_map.items():
        if key in title_lower:
            return level
    return "Mid"


def extract_location(snippet):
    if not snippet:
        return "Unknown"

    
    location_keywords = [
        "Remote", "Bengaluru", "Bangalore", "Hyderabad", "Delhi", "Mumbai", 
        "Pune", "Chennai", "Gurgaon", "Gurugram", "Noida", "Ahmedabad", 
        "Kolkata", "Jaipur", "Chandigarh", "Coimbatore", "Trivandrum", 
        "India", "IN", "IND", "Work from home", "WFH"
    ]

   
    if isinstance(snippet, str):
        snippet = snippet.lower()
    else:
        return "Unknown"

    
    parts = snippet.replace("·", "|").replace("-", "|").replace(",", "|").split("|")
    
    for part in parts:
        part = part.strip().title()  
        for keyword in location_keywords:
            if keyword.lower() in part.lower():
                return part
    
    return "Other"

def search_linkedin_jobs(company, keyword):
    params = {
        "engine": "google",
        "q": f'site:linkedin.com/jobs {keyword} {company}',
        "api_key": SERP_API_KEY,
        "num": 7  
    }

    try:
        client = serpapi.Client(api_key=SERP_API_KEY)
        results = client.search(params)
    except Exception as e:
        print(f"    ❌ Error searching for {keyword} at {company}: {e}")
        return []

    jobs = []
    if "organic_results" in results:
        for result in results["organic_results"]:
            title = result.get("title", "")
            link = result.get("link", "")
            snippet = result.get("snippet", "")

            
            if "/jobs/view/" not in link:
                continue

           
            location = extract_location(snippet)

            
            signal_tags = set()
            for key, tag in signal_map.items():
                if key.lower() in title.lower():
                    signal_tags.add(tag)

            
            dept = get_department(title)
            seniority = get_seniority(title)

            jobs.append({
                "company_name": company,
                "job_title": title,
                "department": dept,
                "location": location,
                "seniority": seniority,
                "job_url": link,
                "growth_signal_tag": ", ".join(signal_tags) if signal_tags else "General Hiring"
            })

    return jobs


def main():
   
    if not SERP_API_KEY or SERP_API_KEY == "your_serpapi_key_here":
        print("❌ Please set your SerpAPI key in the SERP_API_KEY variable")
        return

    all_jobs = []
    total_searches = len(companies) * len(keywords)
    current_search = 0

    for company in companies:
        print(f"\n🔍 Searching for jobs at {company}")
        for keyword in keywords:
            current_search += 1
            print(f"  → Keyword: {keyword} ({current_search}/{total_searches})")
            
            jobs = search_linkedin_jobs(company, keyword)
            all_jobs.extend(jobs)
            
            print(f"    ✅ Found {len(jobs)} jobs")
            
           
            time.sleep(1.5)

    
    if all_jobs:
        df = pd.DataFrame(all_jobs)
        
       
        df = df.drop_duplicates(subset=['job_url'])
        
        
        df = df[[
            "company_name", "job_title", "department", "location", 
            "seniority", "job_url", "growth_signal_tag"
        ]]
        
        df.to_csv("linkedin_job_listings_enhanced.csv", index=False)
        
        print(f"\n✅ Scraped and enriched {len(df)} unique job listings.")
        print("📄 Saved to linkedin_job_listings_enhanced.csv")
        
       
        print(f"\n📊 Enhanced Analytics:")
        print(f"Total unique jobs: {len(df)}")
        
        print(f"\n🏢 Jobs by Company:")
        company_counts = df['company_name'].value_counts()
        for company, count in company_counts.items():
            print(f"  • {company}: {count} jobs")
        
        print(f"\n🏛️ Jobs by Department:")
        dept_counts = df['department'].value_counts()
        for dept, count in dept_counts.items():
            print(f"  • {dept}: {count} jobs")
        
        print(f"\n🎯 Jobs by Seniority:")
        seniority_counts = df['seniority'].value_counts()
        for level, count in seniority_counts.items():
            print(f"  • {level}: {count} jobs")
        
        print(f"\n📍 Jobs by Location:")
        location_counts = df['location'].value_counts()
        for location, count in location_counts.head(10).items():
            print(f"  • {location}: {count} jobs")
        
        print(f"\n🚀 Growth Signals Detected:")
        signal_counts = {}
        for signals in df['growth_signal_tag']:
            if signals and signals != "General Hiring":
                for signal in signals.split(', '):
                    signal_counts[signal] = signal_counts.get(signal, 0) + 1
        
        for signal, count in sorted(signal_counts.items(), key=lambda x: x[1], reverse=True):
            print(f"  • {signal}: {count} jobs")
        
        print(f"\n📋 Sample Results:")
        print(df[['company_name', 'job_title', 'department', 'seniority']].head(3).to_string(index=False))
            
    else:
        print("❌ No jobs found. Please check your API key and search parameters.")

if __name__ == "__main__":
    main()
# Out:
# 🔍 Searching for jobs at Chargebee
#   → Keyword: Product Manager (1/180)
#     ✅ Found 5 jobs
#   → Keyword: Sales Development (2/180)
#     ✅ Found 5 jobs
#   → Keyword: Software Engineer (3/180)
#     ✅ Found 4 jobs
#   → Keyword: UX Designer (4/180)
#     ✅ Found 6 jobs
#   → Keyword: Customer Success (5/180)
#     ✅ Found 6 jobs
#   → Keyword: Marketing (6/180)
#     ✅ Found 6 jobs
#   → Keyword: Data Analyst (7/180)
#     ✅ Found 5 jobs
#   → Keyword: Recruiter (8/180)
#     ✅ Found 7 jobs
#   → Keyword: Engineering Lead (9/180)
#     ✅ Found 6 jobs
#
# 🔍 Searching for jobs at Plum Insurance
#   → Keyword: Product Manager (10/180)
#     ✅ Found 5 jobs
#   → Keyword: Sales Development (11/180)
#     ✅ Found 5 jobs
#   → Keyword: Software Engineer (12/180)
#     ✅ Found 6 jobs
#   → Keyword: UX Designer (13/180)
#     ✅ Found 5 jobs
#   → Keyword: Customer Success (14/180)
#     ✅ Found 5 jobs
#   → Keyword: Marketing (15/180)
#     ✅ Found 4 jobs
#   → Keyword: Data Analyst (16/180)
#     ✅ Found 5 jobs
#   → Keyword: Recruiter (17/180)
#     ✅ Found 6 jobs
#   → Keyword: Engineering Lead (18/180)
#     ✅ Found 4 jobs
#
# 🔍 Searching for jobs at Yellow.ai
#   → Keyword: Product Manager (19/180)
#     ✅ Found 6 jobs
#   → Keyword: Sales Development (20/180)
#     ✅ Found 6 jobs
#   → Keyword: Software Engineer (21/180)
#     ✅ Found 6 jobs
#   → Keyword: UX Designer (22/180)
#     ✅ Found 6 jobs
#   → Keyword: Customer Success (23/180)
#     ✅ Found 7 jobs
#   → Keyword: Marketing (24/180)
#     ✅ Found 7 jobs
#   → Keyword: Data Analyst (25/180)
#     ✅ Found 3 jobs
#   → Keyword: Recruiter (26/180)
#     ✅ Found 7 jobs
#   → Keyword: Engineering Lead (27/180)
#     ✅ Found 7 jobs
#
# 🔍 Searching for jobs at Graphy
#   → Keyword: Product Manager (28/180)
#     ✅ Found 2 jobs
#   → Keyword: Sales Development (29/180)
#     ✅ Found 5 jobs
#   → Keyword: Software Engineer (30/180)
#     ✅ Found 7 jobs
#   → Keyword: UX Designer (31/180)
#     ✅ Found 5 jobs
#   → Keyword: Customer Success (32/180)
#     ✅ Found 5 jobs
#   → Keyword: Marketing (33/180)
#     ✅ Found 4 jobs
#   → Keyword: Data Analyst (34/180)
#     ✅ Found 5 jobs
#   → Keyword: Recruiter (35/180)
#     ✅ Found 7 jobs
#   → Keyword: Engineering Lead (36/180)
#     ✅ Found 6 jobs
#
# 🔍 Searching for jobs at Kala.ai
#   → Keyword: Product Manager (37/180)
#     ✅ Found 7 jobs
#   → Keyword: Sales Development (38/180)
#     ✅ Found 7 jobs
#   → Keyword: Software Engineer (39/180)
#     ✅ Found 7 jobs
#   → Keyword: UX Designer (40/180)
#     ✅ Found 7 jobs
#   → Keyword: Customer Success (41/180)
#     ✅ Found 7 jobs
#   → Keyword: Marketing (42/180)
#     ✅ Found 7 jobs
#   → Keyword: Data Analyst (43/180)
#     ✅ Found 6 jobs
#   → Keyword: Recruiter (44/180)
#     ✅ Found 7 jobs
#   → Keyword: Engineering Lead (45/180)
#     ✅ Found 7 jobs
#
# 🔍 Searching for jobs at Razorpay
#   → Keyword: Product Manager (46/180)
#     ✅ Found 4 jobs
#   → Keyword: Sales Development (47/180)
#     ✅ Found 5 jobs
#   → Keyword: Software Engineer (48/180)
#     ✅ Found 6 jobs
#   → Keyword: UX Designer (49/180)
#     ✅ Found 3 jobs
#   → Keyword: Customer Success (50/180)
#     ✅ Found 5 jobs
#   → Keyword: Marketing (51/180)
#     ✅ Found 6 jobs
#   → Keyword: Data Analyst (52/180)
#     ✅ Found 2 jobs
#   → Keyword: Recruiter (53/180)
#     ✅ Found 6 jobs
#   → Keyword: Engineering Lead (54/180)
#     ✅ Found 7 jobs
#
# 🔍 Searching for jobs at BrowserStack
#   → Keyword: Product Manager (55/180)
#     ✅ Found 6 jobs
#   → Keyword: Sales Development (56/180)
#     ✅ Found 6 jobs
#   → Keyword: Software Engineer (57/180)
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (58/180)
#     ✅ Found 7 jobs
#   → Keyword: Customer Success (59/180)
#     ✅ Found 5 jobs
#   → Keyword: Marketing (60/180)
#     ✅ Found 7 jobs
#   → Keyword: Data Analyst (61/180)
#     ✅ Found 5 jobs
#   → Keyword: Recruiter (62/180)
#     ✅ Found 7 jobs
#   → Keyword: Engineering Lead (63/180)
#     ✅ Found 4 jobs
#
# 🔍 Searching for jobs at Meesho
#   → Keyword: Product Manager (64/180)
#     ✅ Found 7 jobs
#   → Keyword: Sales Development (65/180)
#     ✅ Found 6 jobs
#   → Keyword: Software Engineer (66/180)
#     ✅ Found 7 jobs
#   → Keyword: UX Designer (67/180)
#     ❌ Error searching for UX Designer at Meesho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Meesho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (68/180)
#     ❌ Error searching for Customer Success at Meesho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Meesho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (69/180)
#     ❌ Error searching for Marketing at Meesho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Meesho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (70/180)
#     ❌ Error searching for Data Analyst at Meesho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Meesho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (71/180)
#     ❌ Error searching for Recruiter at Meesho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Meesho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (72/180)
#     ❌ Error searching for Engineering Lead at Meesho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Meesho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Upstox
#   → Keyword: Product Manager (73/180)
#     ❌ Error searching for Product Manager at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (74/180)
#     ❌ Error searching for Sales Development at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (75/180)
#     ❌ Error searching for Software Engineer at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (76/180)
#     ❌ Error searching for UX Designer at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (77/180)
#     ❌ Error searching for Customer Success at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (78/180)
#     ❌ Error searching for Marketing at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (79/180)
#     ❌ Error searching for Data Analyst at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (80/180)
#     ❌ Error searching for Recruiter at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (81/180)
#     ❌ Error searching for Engineering Lead at Upstox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Upstox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Darwinbox
#   → Keyword: Product Manager (82/180)
#     ❌ Error searching for Product Manager at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (83/180)
#     ❌ Error searching for Sales Development at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (84/180)
#     ❌ Error searching for Software Engineer at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (85/180)
#     ❌ Error searching for UX Designer at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (86/180)
#     ❌ Error searching for Customer Success at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (87/180)
#     ❌ Error searching for Marketing at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (88/180)
#     ❌ Error searching for Data Analyst at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (89/180)
#     ❌ Error searching for Recruiter at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (90/180)
#     ❌ Error searching for Engineering Lead at Darwinbox: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Darwinbox&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Zoho
#   → Keyword: Product Manager (91/180)
#     ❌ Error searching for Product Manager at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (92/180)
#     ❌ Error searching for Sales Development at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (93/180)
#     ❌ Error searching for Software Engineer at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (94/180)
#     ❌ Error searching for UX Designer at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (95/180)
#     ❌ Error searching for Customer Success at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (96/180)
#     ❌ Error searching for Marketing at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (97/180)
#     ❌ Error searching for Data Analyst at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (98/180)
#     ❌ Error searching for Recruiter at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (99/180)
#     ❌ Error searching for Engineering Lead at Zoho: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Zoho&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Hasura
#   → Keyword: Product Manager (100/180)
#     ❌ Error searching for Product Manager at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (101/180)
#     ❌ Error searching for Sales Development at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (102/180)
#     ❌ Error searching for Software Engineer at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (103/180)
#     ❌ Error searching for UX Designer at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (104/180)
#     ❌ Error searching for Customer Success at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (105/180)
#     ❌ Error searching for Marketing at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (106/180)
#     ❌ Error searching for Data Analyst at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (107/180)
#     ❌ Error searching for Recruiter at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (108/180)
#     ❌ Error searching for Engineering Lead at Hasura: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Hasura&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Vidyard
#   → Keyword: Product Manager (109/180)
#     ❌ Error searching for Product Manager at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (110/180)
#     ❌ Error searching for Sales Development at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (111/180)
#     ❌ Error searching for Software Engineer at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (112/180)
#     ❌ Error searching for UX Designer at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (113/180)
#     ❌ Error searching for Customer Success at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (114/180)
#     ❌ Error searching for Marketing at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (115/180)
#     ❌ Error searching for Data Analyst at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (116/180)
#     ❌ Error searching for Recruiter at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (117/180)
#     ❌ Error searching for Engineering Lead at Vidyard: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Vidyard&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Fyle
#   → Keyword: Product Manager (118/180)
#     ❌ Error searching for Product Manager at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (119/180)
#     ❌ Error searching for Sales Development at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (120/180)
#     ❌ Error searching for Software Engineer at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (121/180)
#     ❌ Error searching for UX Designer at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (122/180)
#     ❌ Error searching for Customer Success at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (123/180)
#     ❌ Error searching for Marketing at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (124/180)
#     ❌ Error searching for Data Analyst at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (125/180)
#     ❌ Error searching for Recruiter at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (126/180)
#     ❌ Error searching for Engineering Lead at Fyle: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Fyle&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Dunzo
#   → Keyword: Product Manager (127/180)
#     ❌ Error searching for Product Manager at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (128/180)
#     ❌ Error searching for Sales Development at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (129/180)
#     ❌ Error searching for Software Engineer at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (130/180)
#     ❌ Error searching for UX Designer at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (131/180)
#     ❌ Error searching for Customer Success at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (132/180)
#     ❌ Error searching for Marketing at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (133/180)
#     ❌ Error searching for Data Analyst at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (134/180)
#     ❌ Error searching for Recruiter at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (135/180)
#     ❌ Error searching for Engineering Lead at Dunzo: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Dunzo&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at OfBusiness
#   → Keyword: Product Manager (136/180)
#     ❌ Error searching for Product Manager at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (137/180)
#     ❌ Error searching for Sales Development at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (138/180)
#     ❌ Error searching for Software Engineer at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (139/180)
#     ❌ Error searching for UX Designer at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (140/180)
#     ❌ Error searching for Customer Success at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (141/180)
#     ❌ Error searching for Marketing at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (142/180)
#     ❌ Error searching for Data Analyst at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (143/180)
#     ❌ Error searching for Recruiter at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (144/180)
#     ❌ Error searching for Engineering Lead at OfBusiness: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+OfBusiness&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Artivatic
#   → Keyword: Product Manager (145/180)
#     ❌ Error searching for Product Manager at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (146/180)
#     ❌ Error searching for Sales Development at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (147/180)
#     ❌ Error searching for Software Engineer at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (148/180)
#     ❌ Error searching for UX Designer at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (149/180)
#     ❌ Error searching for Customer Success at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (150/180)
#     ❌ Error searching for Marketing at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (151/180)
#     ❌ Error searching for Data Analyst at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (152/180)
#     ❌ Error searching for Recruiter at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (153/180)
#     ❌ Error searching for Engineering Lead at Artivatic: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Artivatic&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Stanza Living
#   → Keyword: Product Manager (154/180)
#     ❌ Error searching for Product Manager at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (155/180)
#     ❌ Error searching for Sales Development at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (156/180)
#     ❌ Error searching for Software Engineer at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (157/180)
#     ❌ Error searching for UX Designer at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (158/180)
#     ❌ Error searching for Customer Success at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (159/180)
#     ❌ Error searching for Marketing at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (160/180)
#     ❌ Error searching for Data Analyst at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (161/180)
#     ❌ Error searching for Recruiter at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (162/180)
#     ❌ Error searching for Engineering Lead at Stanza Living: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Stanza+Living&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Sigtuple
#   → Keyword: Product Manager (163/180)
#     ❌ Error searching for Product Manager at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (164/180)
#     ❌ Error searching for Sales Development at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (165/180)
#     ❌ Error searching for Software Engineer at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (166/180)
#     ❌ Error searching for UX Designer at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (167/180)
#     ❌ Error searching for Customer Success at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (168/180)
#     ❌ Error searching for Marketing at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (169/180)
#     ❌ Error searching for Data Analyst at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (170/180)
#     ❌ Error searching for Recruiter at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (171/180)
#     ❌ Error searching for Engineering Lead at Sigtuple: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Sigtuple&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# 🔍 Searching for jobs at Locus
#   → Keyword: Product Manager (172/180)
#     ❌ Error searching for Product Manager at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Product+Manager+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Sales Development (173/180)
#     ❌ Error searching for Sales Development at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Sales+Development+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Software Engineer (174/180)
#     ❌ Error searching for Software Engineer at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Software+Engineer+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: UX Designer (175/180)
#     ❌ Error searching for UX Designer at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+UX+Designer+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Customer Success (176/180)
#     ❌ Error searching for Customer Success at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Customer+Success+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Marketing (177/180)
#     ❌ Error searching for Marketing at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Marketing+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Data Analyst (178/180)
#     ❌ Error searching for Data Analyst at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Data+Analyst+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Recruiter (179/180)
#     ❌ Error searching for Recruiter at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Recruiter+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#   → Keyword: Engineering Lead (180/180)
#     ❌ Error searching for Engineering Lead at Locus: 429 Client Error: Too Many Requests for url: https://serpapi.com/search?engine=google&q=site%3Alinkedin.com%2Fjobs+Engineering+Lead+Locus&api_key=38100fb1d15ed14424d87cb56b432c03bd7a030d745a6680efc448c2021b82ad&num=7
#     ✅ Found 0 jobs
#
# ✅ Scraped and enriched 320 unique job listings.
# 📄 Saved to linkedin_job_listings_enhanced.csv
#
# 📊 Enhanced Analytics:
# Total unique jobs: 320
#
# 🏢 Jobs by Company:
#   • Kala.ai: 50 jobs
#   • Yellow.ai: 44 jobs
#   • Graphy: 43 jobs
#   • Razorpay: 43 jobs
#   • Chargebee: 42 jobs
#   • Plum Insurance: 41 jobs
#   • BrowserStack: 37 jobs
#   • Meesho: 20 jobs
#
# 🏛️ Jobs by Department:
#   • Engineering: 79 jobs
#   • Other: 55 jobs
#   • Design: 44 jobs
#   • Product: 39 jobs
#   • Sales: 28 jobs
#   • Marketing: 26 jobs
#   • CSM: 26 jobs
#   • Data: 20 jobs
#   • HR: 2 jobs
#   • Support: 1 jobs
#
# 🎯 Jobs by Seniority:
#   • Mid: 206 jobs
#   • Senior: 46 jobs
#   • Lead: 35 jobs
#   • Junior: 18 jobs
#   • Intern: 10 jobs
#   • Director: 4 jobs
#   • VP: 1 jobs
#
# 📍 Jobs by Location:
#   • Other: 14 jobs
#   • Razorpay Is Building A New: 7 jobs
#   • Plum Is An Employee Insurance And Health Benefits Platform Focused On Making Health Insurance Simple: 6 jobs
#   • We'Re Seeking Motivated Individuals For Flexible: 4 jobs
#   • Chargebee Is Seeking A Product Marketing Manager Who Will Play An Integral Role In Supporting Our Growth. In This Role: 2 jobs
#   • And Information Technology ...: 2 jobs
#   • We Focus On Ensuring Platform Stability: 2 jobs
#   • Headquartered In San Mateo: 2 jobs
#   • Plum Is An Employee Insurance And Health Benefits Platform Focused On Making ... Computer Software Engineer Jobs. 45: 2 jobs
#   • Preferably 6/7+ Years Of Relevant Work Experience In Interaction Design: 2 jobs
#
# 🚀 Growth Signals Detected:
#   • Leadership Upgrade: 130 jobs
#   • New Product Initiative: 40 jobs
#   • Go-To-Market Expansion: 35 jobs
#   • Design Overhaul: 26 jobs
#   • Engineering Buildout: 13 jobs
#
# 📋 Sample Results:
# company_name                                                    job_title department seniority
#    Chargebee  Chargebee hiring Product Marketing Manager in Salt Lake ...  Marketing       Mid
#    Chargebee Chargebee hiring Staff Product Manager in Chennai, Tamil ...    Product       Mid
#    Chargebee                 Large Enterprise Program Manager - Chargebee      Other       Mid
